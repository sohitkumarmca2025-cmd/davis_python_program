# %% [markdown]
# <a href="https://colab.research.google.com/github/sohitkumarmca2025-cmd/davis_python_program/blob/main/mataplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
sales = [120,150,170,160,180,200,210,190,220,230,250,270]

plt.plot(months, sales, color='blue', marker='o', linestyle='--')

plt.title("Monthly Sales of Company")
plt.xlabel("Months")
plt.ylabel("Sales")

plt.show()
