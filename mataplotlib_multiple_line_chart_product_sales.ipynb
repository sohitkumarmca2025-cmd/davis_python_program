# %% [markdown]
# <a href="https://colab.research.google.com/github/sohitkumarmca2025-cmd/davis_python_program/blob/main/mataplotlib_multiple_line_chart_product_sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

months = ['Jan','Feb','Mar','Apr','May','Jun']

productA = [100,120,140,130,150,170]
productB = [90,110,120,140,160,180]
productC = [80,100,110,120,140,160]

plt.plot(months, productA, marker='o', label='Product A')
plt.plot(months, productB, marker='s', label='Product B')
plt.plot(months, productC, marker='^', label='Product C')

plt.title("Sales Comparison of Products")
plt.xlabel("Months")
plt.ylabel("Sales")

plt.legend()

plt.show()
